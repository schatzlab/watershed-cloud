# %% [markdown]
# This notebook is only here to remind you to run the Watershed-SNV workflow before moving on to the rest of the notebooks!
#
# Please see this article on how to run a workflow in Terra if you have any questions.
# [Overview: Running workflows in Terra](https://support.terra.bio/hc/en-us/articles/360036379771-Overview-Running-workflows-in-Terra)
#
# In Select Data, choose the row from the table for the set of chromosomes of interest.
#
# The inputs to the workflow do not have to be changed.
#
# Estimated wokflow runtime depends on what set of chromosomes you choose to run:
# * All chromosomes: 4hr 15min
# * chr21 & 22: 25min
# * chr18, 19, & 20: 40min
#
#
# Note: While waiting for the workflow to run you may choose to turn off your virtual machine, but do not delete the persistent disk. If you do, you will have to rerun the previous notebooks.
